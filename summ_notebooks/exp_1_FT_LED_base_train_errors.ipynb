# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# setup colab notebook to have access to hugging face model so it can use it after every checkpoint
# secrets are stored in google colab
from google.colab import userdata
hf_token=userdata.get('hf_token')

# Install Hugging Face hub
# !pip install -q huggingface_hub hf_xet
from huggingface_hub import login
login(token=hf_token)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 MB 46.9 MB/s eta 0:00:00

# %%
# Install transformers, bitsandbytes, PEFT, accelerate and others
# !pip install -q transformers nltk datasets filelock trl
# !pip install -q  wandb evaluate rouge_score bert_score sacrebleu sacremoses
# peft bitsandbytes accelerate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.4/491.4 kB 32.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.0/348.0 kB 32.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 19.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 111.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 98.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# The original paper efforts fine tuned Llama 2 models with a complete grid search for the following parameters:
#
# *   lora rank in {8, 32}
# *   lora alpha in {8, 32}
# *   lora dropout in {0.050.1}
# *   target modules in {[q proj, v proj], [q proj, k - proj, v proj, o proj]}
# *   learning rate in {2e-5, 2e-4}
#
# There were 32 experiments done for fine tuning on Llama 2 7B & 7B model each.

# %% [markdown]
# # Reproduction Task
# Due to the GPU limits, high costs for provisioning GPU instances and time unavailability, we performed only 1 experiment below which took 2 hours to train and predict.
#
# Fine Tune Llama2 7B model with below parameters
# lora rank in {8, 32}
#
# *   lora rank = 8
# *   lora alpha = 8
# *   lora dropout = 0.05
# *   target modules = [q proj, v proj]
# *   learning rate = 2e-5

# %%
# verify the doc string and signature of all parameters in this class
from transformers import Seq2SeqTrainingArguments
help(Seq2SeqTrainingArguments)
# Out:
# Help on class Seq2SeqTrainingArguments in module transformers.training_args_seq2seq:
#
# class Seq2SeqTrainingArguments(transformers.training_args.TrainingArguments)
# ...

# %%
# Initiate the shell script for above experiment
# %%shell
cd /content/drive/MyDrive/DL4H-Project/patient_summaries_with_llms/
ls
chmod +x scripts/parameter_tuning_led_wrapper.sh
bash scripts/parameter_tuning_led_wrapper.sh
# Out:
# scripts  summarization	wandb
# Starting experiment: /content/drive/MyDrive/DL4H-Project/mimic-iv-note-di-bhc/models/led-base-16384/mimic-iv-note-di-bhc_led-base-16384_4000_600_chars_100_valid/dropout_0.05_learning_rate_5e-4
# ------------------------------------------------------------
# SLURM JOB ID:
# Running on nodes:
# ------------------------------------------------------------
# /content/drive/MyDrive/DL4H-Project/patient_summaries_with_llms/scripts/parameter_tuning_led.sh: line 28: ml: command not found
# /content/drive/MyDrive/DL4H-Project/patient_summaries_with_llms/scripts/parameter_tuning_led.sh: line 29: ml: command not found
# Running script
# CUDA_VISIBLE_DEVICES:
# Device: cuda
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/DL4H-Project/patient_summaries_with_llms/summarization/run_summarization.py", line 34, in <module>
# ...

# %%
# !python -c "import transformers; print(transformers.__file__)"
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/__init__.py

# %%
# !pip install --upgrade --quiet transformers

# Restart the runtime after this if needed

# %%
from transformers import Seq2SeqTrainingArguments
help(Seq2SeqTrainingArguments)
# Out:
# Help on class Seq2SeqTrainingArguments in module transformers.training_args_seq2seq:
#
# class Seq2SeqTrainingArguments(transformers.training_args.TrainingArguments)
# ...

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize

# Now you can use the tokenizers
sentences = sent_tokenize("This is a sample text. It contains multiple sentences.")
words = word_tokenize("This is a sample text.")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-1-24e3387ae5d3> in <cell line: 0>()
#       4
#       5 # Now you can use the tokenizers
# ----> 6 sentences = sent_tokenize("This is a sample text. It contains multiple sentences.")
#       7 words = word_tokenize("This is a sample text.")
#
# /usr/local/lib/python3.11/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#     121
#
# /usr/local/lib/python3.11/dist-packages/nltk/tokenize/__init__.py in _get_punkt_tokenizer(language)
#     103     :type language: str
#     104     """
# ...
