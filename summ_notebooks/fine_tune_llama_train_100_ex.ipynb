# %%
from google.colab import userdata
hf_token=userdata.get('hf_token')

# !pip install -q huggingface_hub
from huggingface_hub import login
login(token=hf_token)

# %%
# Install Hugging Face, bitsandbytes, PEFT, accelerate
# !pip install -q transformers peft bitsandbytes accelerate

# !pip install -q datasets trl wandb evaluate rouge_score

# !pip install -q wandb evaluate rouge_score
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 32.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 91.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 107.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.4/491.4 kB 35.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.0/348.0 kB 35.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 22.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 23.9 MB/s eta 0:00:00
#   Building wheel for rouge_score (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# run Llama2 7b model training step
# execute the .sh script

# %%
# %%shell
# cd /content/drive/MyDrive/DL4H-Project/patient_summaries_with_llms/scripts
# ls
# chmod +x parameter_tuning_llama_wrapper.sh
# bash parameter_tuning_llama_wrapper.sh
# Out:
# parameter_tuning_led.sh		 parameter_tuning_llama.sh	    README.md
# parameter_tuning_led_wrapper.sh  parameter_tuning_llama_wrapper.sh
# Starting experiment: /content/drive/MyDrive/DL4H-Project/mimic-iv-note-di-bhc/models/Llama-2-7b-hf/mimic-iv-note-di-bhc_Llama-2-7b-hf_4000_600_chars_100_valid/lora_rank_8_lora_alpha_8_lora_dropout_0.05_num_target_modules_2_learning_rate_2e-5
# ------------------------------------------------------------
# SLURM JOB ID:
# Running on nodes:
# ------------------------------------------------------------
# /content/drive/MyDrive/DL4H-Project/patient_summaries_with_llms/scripts/parameter_tuning_llama.sh: line 38: conda: command not found
# /content/drive/MyDrive/DL4H-Project/patient_summaries_with_llms/scripts/parameter_tuning_llama.sh: line 41: conda: command not found
# Conda environment:
# Running script
# CUDA_VISIBLE_DEVICES:
# - if SLURM_STEP_GPUS is not set, use SLURM_JOB_GPUS
# SLURM GPUs:
# Set CUDA_VISIBLE_DEVICES:
# Device: cuda
# 2025-04-30 04:32:50.286062: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-30 04:32:50.303372: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745987570.325173    5952 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745987570.331786    5952 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-30 04:32:50.353721: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# data: /content/drive/MyDrive/DL4H-Project/mimic-iv-note-di-bhc/dataset
# wandb: Currently logged in as: naveenkcb (naveenkcb-university-of-illinois-urbana-champaign) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.10
# wandb: Run data is saved locally in /content/drive/MyDrive/DL4H-Project/patient_summaries_with_llms/wandb/run-20250430_043300-9c0qipxm
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run frosty-leaf-48
# wandb: ⭐️ View project at https://wandb.ai/naveenkcb-university-of-illinois-urbana-champaign/mimic-iv-note-di-bhc_Llama-2-7b-hf_parameter-tuning
# wandb: 🚀 View run at https://wandb.ai/naveenkcb-university-of-illinois-urbana-champaign/mimic-iv-note-di-bhc_Llama-2-7b-hf_parameter-tuning/runs/9c0qipxm
# config.json: 100% 609/609 [00:00<00:00, 1.92MB/s]
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--meta-llama--Llama-2-7b-hf/snapshots/01c7f73d771dfac7d292323805ebc428287df4f9/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 11008,
#   "max_position_embeddings": 4096,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 32,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 10000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.51.3",
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# Overriding torch_dtype=None with `torch_dtype=torch.float16` due to requirements of `bitsandbytes` to enable model loading in 8-bit or 4-bit. Pass your own torch_dtype to specify the dtype of the remaining non-linear layers or pass torch_dtype=torch.float16 to remove this warning.
# model.safetensors.index.json: 100% 26.8k/26.8k [00:00<00:00, 62.9MB/s]
# loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--meta-llama--Llama-2-7b-hf/snapshots/01c7f73d771dfac7d292323805ebc428287df4f9/model.safetensors.index.json
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0% 0.00/9.98G [00:00<?, ?B/s]
#
# model-00002-of-00002.safetensors:   0% 0.00/3.50G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0% 41.9M/9.98G [00:00<00:25, 394MB/s]
#
# model-00002-of-00002.safetensors:   1% 21.0M/3.50G [00:00<00:22, 153MB/s]
# model-00001-of-00002.safetensors:   1% 94.4M/9.98G [00:00<00:23, 422MB/s]
#
# model-00002-of-00002.safetensors:   2% 73.4M/3.50G [00:00<00:10, 314MB/s]
# model-00001-of-00002.safetensors:   1% 147M/9.98G [00:00<00:22, 442MB/s]
#
# model-00002-of-00002.safetensors:   4% 126M/3.50G [00:00<00:08, 379MB/s]
# model-00001-of-00002.safetensors:   2% 199M/9.98G [00:00<00:21, 458MB/s]
#
# model-00002-of-00002.safetensors:   5% 178M/3.50G [00:00<00:07, 417MB/s]
# model-00001-of-00002.safetensors:   3% 252M/9.98G [00:00<00:20, 464MB/s]
#
# model-00002-of-00002.safetensors:   7% 231M/3.50G [00:00<00:07, 426MB/s]
# model-00001-of-00002.safetensors:   3% 304M/9.98G [00:00<00:21, 448MB/s]
#
# model-00002-of-00002.safetensors:   8% 283M/3.50G [00:00<00:07, 426MB/s]
# model-00001-of-00002.safetensors:   4% 357M/9.98G [00:00<00:21, 445MB/s]
#
# model-00002-of-00002.safetensors:  10% 336M/3.50G [00:00<00:07, 440MB/s]
# model-00001-of-00002.safetensors:   4% 409M/9.98G [00:00<00:20, 458MB/s]
#
# model-00002-of-00002.safetensors:  11% 388M/3.50G [00:00<00:06, 453MB/s]
# model-00001-of-00002.safetensors:   5% 461M/9.98G [00:01<00:20, 468MB/s]
#
# model-00002-of-00002.safetensors:  13% 440M/3.50G [00:01<00:06, 443MB/s]
# model-00001-of-00002.safetensors:   5% 514M/9.98G [00:01<00:20, 466MB/s]
#
# model-00002-of-00002.safetensors:  14% 493M/3.50G [00:01<00:06, 459MB/s]
# model-00001-of-00002.safetensors:   6% 566M/9.98G [00:01<00:21, 441MB/s]
#
# model-00002-of-00002.safetensors:  16% 556M/3.50G [00:01<00:06, 474MB/s]
# model-00001-of-00002.safetensors:   6% 619M/9.98G [00:01<00:21, 433MB/s]
#
# model-00002-of-00002.safetensors:  17% 608M/3.50G [00:01<00:06, 452MB/s]
# model-00001-of-00002.safetensors:   7% 671M/9.98G [00:01<00:23, 388MB/s]
#
# model-00002-of-00002.safetensors:  19% 661M/3.50G [00:01<00:07, 371MB/s]
# model-00001-of-00002.safetensors:   7% 713M/9.98G [00:01<00:37, 249MB/s]
#
# model-00002-of-00002.safetensors:  20% 703M/3.50G [00:01<00:11, 252MB/s]
# model-00001-of-00002.safetensors:   8% 755M/9.98G [00:02<00:41, 221MB/s]
#
# model-00002-of-00002.safetensors:  21% 744M/3.50G [00:02<00:12, 221MB/s]
# model-00001-of-00002.safetensors:   8% 786M/9.98G [00:02<00:45, 200MB/s]
#
# model-00002-of-00002.safetensors:  22% 776M/3.50G [00:02<00:13, 196MB/s]
# model-00001-of-00002.safetensors:   8% 818M/9.98G [00:02<00:51, 177MB/s]
#
# model-00002-of-00002.safetensors:  23% 807M/3.50G [00:02<00:15, 169MB/s]
# model-00001-of-00002.safetensors:   8% 839M/9.98G [00:02<00:58, 157MB/s]
#
# model-00002-of-00002.safetensors:  24% 828M/3.50G [00:02<00:20, 133MB/s]
# model-00001-of-00002.safetensors:   9% 860M/9.98G [00:03<01:22, 110MB/s]
#
# model-00002-of-00002.safetensors:  24% 849M/3.50G [00:03<00:24, 106MB/s]
# model-00001-of-00002.safetensors:   9% 881M/9.98G [00:03<01:28, 103MB/s]
#
# model-00002-of-00002.safetensors:  25% 870M/3.50G [00:03<00:23, 113MB/s]
# model-00001-of-00002.safetensors:   9% 902M/9.98G [00:03<01:18, 116MB/s]
#
# model-00002-of-00002.safetensors:  25% 891M/3.50G [00:03<00:20, 126MB/s]
# model-00001-of-00002.safetensors:   9% 933M/9.98G [00:03<01:03, 142MB/s]
#
# model-00002-of-00002.safetensors:  26% 923M/3.50G [00:03<00:16, 159MB/s]
# model-00001-of-00002.safetensors:  10% 975M/9.98G [00:03<00:47, 189MB/s]
#
# model-00002-of-00002.safetensors:  28% 965M/3.50G [00:03<00:12, 209MB/s]
# model-00001-of-00002.safetensors:  10% 1.02G/9.98G [00:03<00:38, 235MB/s]
#
# model-00002-of-00002.safetensors:  29% 1.01G/3.50G [00:03<00:09, 252MB/s]
# model-00001-of-00002.safetensors:  11% 1.06G/9.98G [00:04<00:33, 269MB/s]
#
# model-00002-of-00002.safetensors:  30% 1.05G/3.50G [00:04<00:08, 277MB/s]
# model-00001-of-00002.safetensors:  11% 1.11G/9.98G [00:04<00:28, 310MB/s]
#
# model-00002-of-00002.safetensors:  31% 1.10G/3.50G [00:04<00:07, 327MB/s]
# model-00001-of-00002.safetensors:  12% 1.15G/9.98G [00:04<00:31, 283MB/s]
#
# model-00002-of-00002.safetensors:  33% 1.14G/3.50G [00:04<00:08, 291MB/s]
# model-00001-of-00002.safetensors:  12% 1.18G/9.98G [00:04<00:46, 187MB/s]
#
# model-00002-of-00002.safetensors:  34% 1.18G/3.50G [00:04<00:11, 196MB/s]
# model-00001-of-00002.safetensors:  12% 1.23G/9.98G [00:04<00:39, 224MB/s]
#
# model-00002-of-00002.safetensors:  35% 1.24G/3.50G [00:04<00:09, 242MB/s]
# model-00001-of-00002.safetensors:  13% 1.27G/9.98G [00:06<02:48, 51.7MB/s]
#
# model-00002-of-00002.safetensors:  36% 1.27G/3.50G [00:06<00:42, 52.8MB/s]
# model-00001-of-00002.safetensors:  13% 1.32G/9.98G [00:07<01:54, 75.9MB/s]
#
# model-00002-of-00002.safetensors:  38% 1.32G/3.50G [00:07<00:28, 77.5MB/s]
# model-00001-of-00002.safetensors:  14% 1.38G/9.98G [00:07<01:16, 112MB/s]
#
# model-00002-of-00002.safetensors:  39% 1.35G/3.50G [00:07<00:22, 93.4MB/s]
# model-00001-of-00002.safetensors:  14% 1.43G/9.98G [00:07<01:01, 138MB/s]
#
# model-00002-of-00002.safetensors:  40% 1.39G/3.50G [00:07<00:17, 122MB/s]
# model-00001-of-00002.safetensors:  15% 1.47G/9.98G [00:07<00:51, 165MB/s]
#
# model-00002-of-00002.safetensors:  41% 1.45G/3.50G [00:07<00:12, 164MB/s]
# model-00001-of-00002.safetensors:  15% 1.51G/9.98G [00:07<00:42, 199MB/s]
#
# model-00002-of-00002.safetensors:  43% 1.50G/3.50G [00:07<00:09, 207MB/s]
# model-00001-of-00002.safetensors:  16% 1.56G/9.98G [00:07<00:34, 244MB/s]
#
# model-00002-of-00002.safetensors:  44% 1.54G/3.50G [00:07<00:08, 240MB/s]
# model-00001-of-00002.safetensors:  16% 1.61G/9.98G [00:07<00:29, 286MB/s]
#
# model-00002-of-00002.safetensors:  45% 1.58G/3.50G [00:07<00:07, 260MB/s]
# model-00001-of-00002.safetensors:  17% 1.67G/9.98G [00:07<00:25, 325MB/s]
#
# model-00002-of-00002.safetensors:  47% 1.64G/3.50G [00:07<00:06, 296MB/s]
# model-00001-of-00002.safetensors:  17% 1.72G/9.98G [00:07<00:23, 351MB/s]
#
# model-00002-of-00002.safetensors:  48% 1.68G/3.50G [00:08<00:05, 304MB/s]
# model-00001-of-00002.safetensors:  18% 1.77G/9.98G [00:08<00:21, 386MB/s]
#
# model-00002-of-00002.safetensors:  49% 1.73G/3.50G [00:08<00:05, 338MB/s]
# model-00001-of-00002.safetensors:  18% 1.82G/9.98G [00:08<00:19, 408MB/s]
# model-00001-of-00002.safetensors:  19% 1.88G/9.98G [00:08<00:19, 424MB/s]
#
# model-00002-of-00002.safetensors:  51% 1.77G/3.50G [00:08<00:06, 267MB/s]
# model-00001-of-00002.safetensors:  19% 1.93G/9.98G [00:08<00:18, 444MB/s]
#
# model-00002-of-00002.safetensors:  52% 1.81G/3.50G [00:08<00:05, 292MB/s]
# model-00001-of-00002.safetensors:  20% 1.98G/9.98G [00:11<02:13, 59.7MB/s]
#
# model-00002-of-00002.safetensors:  53% 1.86G/3.50G [00:11<00:34, 48.2MB/s]
# model-00001-of-00002.safetensors:  20% 2.02G/9.98G [00:11<01:50, 71.9MB/s]
#
# model-00002-of-00002.safetensors:  54% 1.89G/3.50G [00:11<00:27, 59.2MB/s]
# model-00001-of-00002.safetensors:  21% 2.08G/9.98G [00:11<01:21, 97.3MB/s]
#
# model-00002-of-00002.safetensors:  55% 1.93G/3.50G [00:11<00:19, 79.3MB/s]
# model-00001-of-00002.safetensors:  21% 2.13G/9.98G [00:11<01:01, 128MB/s]
#
# model-00002-of-00002.safetensors:  56% 1.96G/3.50G [00:11<00:15, 97.0MB/s]
# model-00001-of-00002.safetensors:  22% 2.18G/9.98G [00:11<00:47, 165MB/s]
#
# model-00002-of-00002.safetensors:  57% 2.00G/3.50G [00:11<00:11, 126MB/s]
# model-00001-of-00002.safetensors:  22% 2.23G/9.98G [00:11<00:37, 206MB/s]
#
# model-00002-of-00002.safetensors:  58% 2.03G/3.50G [00:11<00:09, 148MB/s]
# model-00001-of-00002.safetensors:  23% 2.29G/9.98G [00:11<00:31, 247MB/s]
#
# model-00002-of-00002.safetensors:  59% 2.08G/3.50G [00:11<00:07, 185MB/s]
# model-00001-of-00002.safetensors:  23% 2.34G/9.98G [00:12<00:26, 287MB/s]
#
# model-00002-of-00002.safetensors:  61% 2.12G/3.50G [00:12<00:06, 199MB/s]
# model-00001-of-00002.safetensors:  24% 2.39G/9.98G [00:12<00:25, 299MB/s]
#
# model-00002-of-00002.safetensors:  61% 2.15G/3.50G [00:12<00:06, 213MB/s]
# model-00001-of-00002.safetensors:  24% 2.44G/9.98G [00:12<00:22, 332MB/s]
#
# model-00002-of-00002.safetensors:  62% 2.18G/3.50G [00:12<00:05, 220MB/s]
# model-00001-of-00002.safetensors:  25% 2.50G/9.98G [00:12<00:20, 359MB/s]
#
# model-00002-of-00002.safetensors:  64% 2.22G/3.50G [00:12<00:05, 254MB/s]
# model-00001-of-00002.safetensors:  26% 2.55G/9.98G [00:12<00:19, 380MB/s]
#
# model-00002-of-00002.safetensors:  65% 2.26G/3.50G [00:12<00:04, 276MB/s]
# model-00001-of-00002.safetensors:  26% 2.60G/9.98G [00:12<00:19, 387MB/s]
#
# model-00002-of-00002.safetensors:  66% 2.32G/3.50G [00:12<00:03, 322MB/s]
#
# model-00002-of-00002.safetensors:  67% 2.36G/3.50G [00:12<00:03, 290MB/s]
# model-00001-of-00002.safetensors:  27% 2.65G/9.98G [00:12<00:23, 314MB/s]
#
# model-00002-of-00002.safetensors:  69% 2.40G/3.50G [00:13<00:04, 258MB/s]
# model-00001-of-00002.safetensors:  27% 2.69G/9.98G [00:13<00:25, 282MB/s]
#
# model-00002-of-00002.safetensors:  69% 2.43G/3.50G [00:13<00:04, 239MB/s]
# model-00001-of-00002.safetensors:  27% 2.74G/9.98G [00:13<00:29, 247MB/s]
#
# model-00002-of-00002.safetensors:  70% 2.46G/3.50G [00:13<00:04, 220MB/s]
# model-00001-of-00002.safetensors:  28% 2.77G/9.98G [00:13<00:32, 225MB/s]
#
# model-00002-of-00002.safetensors:  71% 2.50G/3.50G [00:13<00:04, 201MB/s]
# model-00001-of-00002.safetensors:  28% 2.80G/9.98G [00:13<00:35, 203MB/s]
#
# model-00002-of-00002.safetensors:  72% 2.53G/3.50G [00:13<00:05, 188MB/s]
#
# model-00002-of-00002.safetensors:  73% 2.55G/3.50G [00:13<00:05, 167MB/s]
# model-00001-of-00002.safetensors:  28% 2.83G/9.98G [00:14<00:49, 144MB/s]
#
# model-00002-of-00002.safetensors:  73% 2.57G/3.50G [00:14<00:06, 153MB/s]
# model-00001-of-00002.safetensors:  29% 2.86G/9.98G [00:14<00:42, 167MB/s]
#
# model-00002-of-00002.safetensors:  74% 2.59G/3.50G [00:14<00:06, 145MB/s]
# model-00001-of-00002.safetensors:  29% 2.89G/9.98G [00:14<00:45, 156MB/s]
#
# model-00002-of-00002.safetensors:  75% 2.61G/3.50G [00:14<00:06, 139MB/s]
# model-00001-of-00002.safetensors:  29% 2.92G/9.98G [00:14<00:45, 155MB/s]
#
# model-00002-of-00002.safetensors:  75% 2.63G/3.50G [00:14<00:05, 148MB/s]
# model-00001-of-00002.safetensors:  29% 2.94G/9.98G [00:14<00:42, 165MB/s]
#
# model-00002-of-00002.safetensors:  76% 2.65G/3.50G [00:14<00:05, 160MB/s]
# model-00001-of-00002.safetensors:  30% 2.97G/9.98G [00:14<00:38, 184MB/s]
#
# model-00002-of-00002.safetensors:  77% 2.68G/3.50G [00:14<00:04, 185MB/s]
# model-00001-of-00002.safetensors:  30% 2.99G/9.98G [00:14<00:38, 180MB/s]
#
# model-00002-of-00002.safetensors:  77% 2.71G/3.50G [00:16<00:20, 38.2MB/s]
# model-00001-of-00002.safetensors:  30% 3.01G/9.98G [00:19<06:27, 18.0MB/s]
#
# model-00002-of-00002.safetensors:  78% 2.73G/3.50G [00:19<00:40, 19.0MB/s]
#
# model-00002-of-00002.safetensors:  79% 2.77G/3.50G [00:19<00:22, 32.1MB/s]
#
# model-00002-of-00002.safetensors:  80% 2.79G/3.50G [00:19<00:18, 38.5MB/s]
#
# model-00002-of-00002.safetensors:  81% 2.83G/3.50G [00:19<00:10, 60.9MB/s]
#
# model-00002-of-00002.safetensors:  82% 2.86G/3.50G [00:19<00:08, 79.3MB/s]
#
# model-00002-of-00002.safetensors:  83% 2.89G/3.50G [00:19<00:06, 97.9MB/s]
#
# model-00002-of-00002.safetensors:  84% 2.93G/3.50G [00:20<00:05, 113MB/s]
#
# model-00002-of-00002.safetensors:  84% 2.96G/3.50G [00:20<00:04, 121MB/s]
#
# model-00002-of-00002.safetensors:  85% 2.98G/3.50G [00:20<00:04, 125MB/s]
#
# model-00002-of-00002.safetensors:  86% 3.00G/3.50G [00:20<00:03, 128MB/s]
#
# model-00002-of-00002.safetensors:  86% 3.02G/3.50G [00:20<00:03, 128MB/s]
#
# model-00002-of-00002.safetensors:  87% 3.04G/3.50G [00:20<00:03, 126MB/s]
#
# model-00002-of-00002.safetensors:  87% 3.06G/3.50G [00:21<00:03, 120MB/s]
#
# model-00002-of-00002.safetensors:  88% 3.08G/3.50G [00:21<00:03, 119MB/s]
#
# model-00002-of-00002.safetensors:  89% 3.10G/3.50G [00:21<00:02, 134MB/s]
#
# model-00002-of-00002.safetensors:  89% 3.12G/3.50G [00:21<00:02, 147MB/s]
#
# model-00002-of-00002.safetensors:  91% 3.18G/3.50G [00:21<00:01, 231MB/s]
#
# model-00002-of-00002.safetensors:  92% 3.23G/3.50G [00:21<00:00, 301MB/s]
#
# model-00002-of-00002.safetensors:  94% 3.28G/3.50G [00:21<00:00, 356MB/s]
# model-00001-of-00002.safetensors:  31% 3.05G/9.98G [00:21<06:51, 16.8MB/s]
#
# model-00002-of-00002.safetensors:  95% 3.32G/3.50G [00:21<00:00, 372MB/s]
#
# model-00002-of-00002.safetensors:  97% 3.39G/3.50G [00:22<00:00, 423MB/s]
# model-00001-of-00002.safetensors:  31% 3.08G/9.98G [00:22<04:56, 23.3MB/s]
# model-00001-of-00002.safetensors:  31% 3.12G/9.98G [00:22<03:12, 35.6MB/s]
# model-00001-of-00002.safetensors:  32% 3.17G/9.98G [00:22<02:10, 52.0MB/s]
#
# model-00002-of-00002.safetensors:  98% 3.44G/3.50G [00:22<00:00, 270MB/s]
# model-00001-of-00002.safetensors:  32% 3.21G/9.98G [00:22<01:32, 73.1MB/s]
#
# model-00002-of-00002.safetensors: 100% 3.50G/3.50G [00:22<00:00, 155MB/s]
#
# model-00001-of-00002.safetensors:  33% 3.26G/9.98G [00:22<01:03, 106MB/s]
# model-00001-of-00002.safetensors:  93% 9.25G/9.98G [00:42<00:02, 339MB/s]
# model-00001-of-00002.safetensors:  93% 9.29G/9.98G [00:42<00:02, 283MB/s]
# model-00001-of-00002.safetensors:  93% 9.32G/9.98G [00:42<00:02, 262MB/s]
# model-00001-of-00002.safetensors:  94% 9.37G/9.98G [00:42<00:01, 309MB/s]
# model-00001-of-00002.safetensors:  94% 9.42G/9.98G [00:42<00:01, 313MB/s]
# model-00001-of-00002.safetensors:  95% 9.46G/9.98G [00:43<00:01, 299MB/s]
# model-00001-of-00002.safetensors:  95% 9.49G/9.98G [00:43<00:01, 282MB/s]
# model-00001-of-00002.safetensors:  95% 9.52G/9.98G [00:43<00:01, 267MB/s]
# model-00001-of-00002.safetensors:  96% 9.55G/9.98G [00:43<00:01, 257MB/s]
# model-00001-of-00002.safetensors:  96% 9.58G/9.98G [00:43<00:01, 239MB/s]
# model-00001-of-00002.safetensors:  96% 9.62G/9.98G [00:43<00:01, 226MB/s]
# model-00001-of-00002.safetensors:  97% 9.65G/9.98G [00:43<00:01, 210MB/s]
# model-00001-of-00002.safetensors:  97% 9.68G/9.98G [00:44<00:01, 213MB/s]
# model-00001-of-00002.safetensors:  98% 9.73G/9.98G [00:44<00:00, 264MB/s]
# model-00001-of-00002.safetensors:  98% 9.76G/9.98G [00:44<00:00, 269MB/s]
# model-00001-of-00002.safetensors:  98% 9.80G/9.98G [00:44<00:00, 259MB/s]
# model-00001-of-00002.safetensors:  99% 9.85G/9.98G [00:44<00:00, 294MB/s]
# model-00001-of-00002.safetensors:  99% 9.90G/9.98G [00:44<00:00, 345MB/s]
# model-00001-of-00002.safetensors: 100% 9.98G/9.98G [00:44<00:00, 222MB/s]
# Fetching 2 files: 100% 2/2 [00:45<00:00, 22.63s/it]
# Instantiating LlamaForCausalLM model under default dtype torch.float16.
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "eos_token_id": 2
# }
#
# target_dtype {target_dtype} is replaced by `torch.int8` for 8-bit BnB quantization
# Loading checkpoint shards: 100% 2/2 [00:16<00:00,  8.01s/it]
# All model checkpoint weights were used when initializing LlamaForCausalLM.
#
# All the weights of LlamaForCausalLM were initialized from the model checkpoint at meta-llama/Llama-2-7b-hf.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use LlamaForCausalLM for predictions without further training.
# generation_config.json: 100% 188/188 [00:00<00:00, 884kB/s]
# loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--meta-llama--Llama-2-7b-hf/snapshots/01c7f73d771dfac7d292323805ebc428287df4f9/generation_config.json
# Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "do_sample": true,
#   "eos_token_id": 2,
#   "max_length": 4096,
#   "pad_token_id": 0,
#   "temperature": 0.6,
#   "top_p": 0.9
# }
#
# tokenizer_config.json: 100% 776/776 [00:00<00:00, 2.90MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 40.3MB/s]
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 2.04MB/s]
# special_tokens_map.json: 100% 414/414 [00:00<00:00, 2.04MB/s]
# loading file tokenizer.model from cache at /root/.cache/huggingface/hub/models--meta-llama--Llama-2-7b-hf/snapshots/01c7f73d771dfac7d292323805ebc428287df4f9/tokenizer.model
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--meta-llama--Llama-2-7b-hf/snapshots/01c7f73d771dfac7d292323805ebc428287df4f9/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--meta-llama--Llama-2-7b-hf/snapshots/01c7f73d771dfac7d292323805ebc428287df4f9/special_tokens_map.json
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--meta-llama--Llama-2-7b-hf/snapshots/01c7f73d771dfac7d292323805ebc428287df4f9/tokenizer_config.json
# loading file chat_template.jinja from cache at None
# Loading data from {'train': '/content/drive/MyDrive/DL4H-Project/mimic-iv-note-di-bhc/dataset/train_4000_600_chars_251-350_pt.json', 'validation': '/content/drive/MyDrive/DL4H-Project/mimic-iv-note-di-bhc/dataset/valid_4000_600_chars.json', 'test': '/content/drive/MyDrive/DL4H-Project/mimic-iv-note-di-bhc/dataset/valid_4000_600_chars.json'}
# Generating train split: 100 examples [00:00, 5735.33 examples/s]
# Generating validation split: 2608 examples [00:00, 3162.99 examples/s]
# Generating test split: 2608 examples [00:00, 89147.42 examples/s]
# Number of training examples: 100
# Number of validation examples: 100
# Number of test examples: 100
# Map: 100% 100/100 [00:00<00:00, 387.64 examples/s]
# Map: 100% 100/100 [00:00<00:00, 387.97 examples/s]
# Map: 100% 100/100 [00:00<00:00, 386.75 examples/s]
# Truncated texts: 0 train, 0 val, 0 test
# Prompted train example:
# Summarize for the patient what happened during the hospital stay based on this doctor's note:
# Brief Hospital Course: Ms. ___ was admitted on ___ for dobhoff placement, with open non healing wounds of the lower abdomen, feet and coccyx in the setting severe malnutrition. Nutrition was consulted and concurred with dobhoff placement and provided tube feed recommendations. Solid diet with supplement is also recommended. Plastic surgery was consulted for your abdominal wounds and felt there was no concern for infection and that there more optimal nutrition status is required before unhealthy tissue can be removed. Plastics recommended follow up outpatient in ___ weeks. Podiatry surgery was also consulted for evaluation of bilateral dry, gangrenous digits but found no surrounding infection. Thus, there was no urgent surgical intervention indicated at this time. Given such, IV antibiotics was discontinued. Medicine was consulted for failure to thrive and sunset dementia, which was attributed to dry gangrene and being hospitalized. Outpatient follow up with oncology is recommended given her history of CML status post bone marrow transplant. Mirtazapine 30' QHS was started to stimulate appetite, with seemingly improved her appetite. Neuro: Toe pain was controlled with acetaminophen prn and home tramadol. Patient experienced delirium which was attributed to change in environment. Sleep hygiene and orientation was practiced with improved results. In addition to home Escitalopram, Mirtazapine 30' QHS was started to stimulate appetite, with seemingly improved her appetite. CV: home amlodipine, aspirin, atorvastatin were given. Vitals were monitored routinely and she was hemodynamically stable Resp: She is hemodynamically stable from respiratory standpoint with frequent OOB and IS use. GI: Dobhoff was placed on ___ with Nepro started per Nutrition's recommendation. On ___ during a delirius episode, dobhoff was self-removed. A new dobhoff was replaced and position was confirmed. Tube feed was switched to Jevity. She was on a diabetic diet with good PO intake. GU: Adult diaper was on for incontinence, and patient's ins and outs were recorded. ID: IV vancomycin, cipro, and flaygl were started empirically. Given dry gangrene and podiatry recommendation of no concerning osteomyelitis, IV antibiotics were stopped. White blood count has been stably elevated, known as chronic condition. Medicine recommended outpatient oncology follow up. Otherwise, she was afebrile during this admission. Endo: given tube feed and nutrients being restarted, insulin requirement was resumed as metformin was held. She is currently on Glargine 13Unit at dinner and regular sliding scale. At time of discharge, she was able to tolerate a regular diet and tube feed, get out of bed and ambulate with assistance and rollerwalker, void without issues, and pain was controlled on oral medications alone. She was deemed ready for discharge to rehab (expected rehab stay less than 30 days), and was given the appropriate discharge and follow-up instructions.
# Summary for the patient: You were admitted secondary to open non healing wounds of the lower abdomen, feet and coccyx in the setting severe malnutrition. We consulted nutrition who suggested that we place a temporary feeding tube through your nose into your stomach to supplement your nutitional intake. We feel this is the best option to get your wounds to heal. Plastic surgery was consulted for your abdominal wounds and felt there was no concern for infection and that there was no unhealthy tissue to be removed at this time. Podiatry surgery was also consulted for evaluation of your bilateral dry, gangrenous digits but found no surrounding infection. Thus, there was no urgent surgical intervention indicated at this time. It is imperative that we quickly get your abdominal wounds to heal as quickly as possible so we can proceed with bilateral axillofemoral bypasses to improve flow to feet to avoid bilateral below the knee ampuations. Ms. </s>
#
# Prompted valid example:
# Summarize for the patient what happened during the hospital stay based on this doctor's note:
# Brief Hospital Course: ___ is a ___ year old female without significant PMHx who presented as a transfer from OSH with c/f seizures. Per the history she had an altercation with her boyfriend which involved her getting hit in the head with a trash can. Following this altercation she had shaking episodes and was taken by EMS to ___. She was treated for status with Ativan/midaz and loaded with keppra. Subsequently she was transferred to ___ and admitted to neurology for EEG monitoring. She had a captured event on EEG o/n ___ with shaking without electrographic correlate, consistent with a non-epileptic spell. She was taken off of EEG and had an additional spell of similar semiology. She had post-spell numbness of the left arm that began in her mid-deltoid and was circumferential, crossing multiple dermatomes without clear pattern. She also reported monocular double vision and had difficulty with finger counting even with central visual field testing, consistently naming "2s" as "1" and "5" as "4s". While we cannot rule out seizures occurring prior to admission, this seems less likely given reports of 5 extended episodes and normal EEG (hooked up within 12 hrs of episode). Social work evaluated the patient out of concern for home safety and provided the patient with multiple resources and other contact info. She was discharged home in stable condition without anti-seizure medication. TI === [] Patient does not have insurance and does not have a PCP [] ensure patient feels safe at home - follow-up scheduled with Neurology to ensure some form of continuity of care in ___ when patient reportedly gets insurance
# Summary for the patient: You were admitted to the hospital out of concern for shaking episodes after reported head injury. There was initial concern for seizures and you were given a seizure medication (keppra) which made you very tired. Because you were so tired, you were were transferred to ___ for further monitoring, in case you may have another event that was suspicion for a seizure. You were monitored overnight while on EEG. You had another shaking episode. This event was recorded on EEG and there was no abnormal activity detected, which means that your events that we saw are not seizures. The events that you have are called "psychogenic non-epileptic spells." We did not start you on any seizure medications as these events are your body's response to stress. It is likely that your events are related to ongoing stressors in your life and we had our social workers see you to help set you up with resources at home. We attempted to set you up with a primary care provider, but you do not have insurance. We still scheduled you for an appointment listed below. If you are unable to make that appointment, you should still attempt to set up a primary care provider at your earliest convenience. You reportedly have insurance in ___. Because of this, we scheduled you for neurology follow-up after the month of ___. Neurology follow-up is not necessary for your shaking episodes but they may help you cope with your response to stress. </s>
# You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embedding dimension will be 32001. This might induce some performance reduction as *Tensor Cores* will not be available. For more details about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# The new lm_head weights will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# using `logging_steps` to initialize `eval_steps` to 10
# PyTorch: setting up devices
# PyTorch: setting up devices
# loading file tokenizer.model from cache at /root/.cache/huggingface/hub/models--meta-llama--Llama-2-7b-hf/snapshots/01c7f73d771dfac7d292323805ebc428287df4f9/tokenizer.model
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--meta-llama--Llama-2-7b-hf/snapshots/01c7f73d771dfac7d292323805ebc428287df4f9/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--meta-llama--Llama-2-7b-hf/snapshots/01c7f73d771dfac7d292323805ebc428287df4f9/special_tokens_map.json
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--meta-llama--Llama-2-7b-hf/snapshots/01c7f73d771dfac7d292323805ebc428287df4f9/tokenizer_config.json
# loading file chat_template.jinja from cache at None
# Applying formatting function to train dataset: 100% 100/100 [00:00<00:00, 10011.23 examples/s]
# Converting train dataset to ChatML: 100% 100/100 [00:00<00:00, 14898.78 examples/s]
# Adding EOS to train dataset: 100% 100/100 [00:00<00:00, 12107.92 examples/s]
# Tokenizing train dataset: 100% 100/100 [00:00<00:00, 409.38 examples/s]
# Truncating train dataset: 100% 100/100 [00:00<00:00, 20419.18 examples/s]
# Applying formatting function to eval dataset: 100% 100/100 [00:00<00:00, 10661.68 examples/s]
# Converting eval dataset to ChatML: 100% 100/100 [00:00<00:00, 14993.04 examples/s]
# Adding EOS to eval dataset: 100% 100/100 [00:00<00:00, 12229.36 examples/s]
# Tokenizing eval dataset: 100% 100/100 [00:00<00:00, 415.66 examples/s]
# Truncating eval dataset: 100% 100/100 [00:00<00:00, 23804.22 examples/s]
# max_steps is given, it will override any value given in num_train_epochs
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# The following columns in the training set don't have a corresponding argument in `PeftModelForCausalLM.forward` and have been ignored: text, summary, truncated. If text, summary, truncated are not expected by `PeftModelForCausalLM.forward`,  you can safely ignore this message.
# ***** Running training *****
#   Num examples = 100
#   Num Epochs = 17
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 16
#   Total optimization steps = 100
#   Number of trainable parameters = 4,194,304
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
#   0% 0/100 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/trl/trainer/utils.py:150: UserWarning: Could not find response key `[26289, 363, 278, 16500, 29901]` in the following instance: <s> Summarize for the patient what happened during the hospital stay based on this doctor's note:
# Brief Hospital Course: Dr. ___ is a ___ yo M with h/o tongue CA s/p resection, radiation, and LND as well as recurrent esophageal stenoses s/p ongoing dilatations who is transfered from ___ for further management of multifocal pneumonia. #Multifocal Pneumonia secondary to MRSA, MSSA and Strep: Patient recently suffered multiple broken ribs due to a mechanical fall, developed respiratory symptoms and fevers and presented to his local community hospital. Sputum initially grew strep pneumo and MSSA. Sepsis resolved and he was clinically improving and afebrile for several days so coverage was narrowed to Naficillin; however, additional cultures were forwarded from OSH, which showed MRSA. Nafcillin was switched to vancomycin. ID consult agreed with this choice and recommended 3 weeks of vancomycin monotherapy. He did have evidence of right pleural effusion so chest tube was placed by IP. Pleural fluid studies showed sterile exudate, consistent with parapneumonic effusion. Cytologic evaluation of the pleural fluid is pending at the time of discharge. ___ pathology department has requested the pathology specimens from the patient's past malignancy for comparison. Vancomycin was switched to linezolid per ID recommendation. The patient will complete a course of 2 additional weeks of linezolid after discharge. Rib fracture pain was controlled with tylenol, oxycodone and lidocaine patch. #Troponemia: Most likely secondary to demand. Appears to be .12 on last check at OSH. He never had any chest pain or concerning ECG changes. This was rechecked on admission to ___ and found to be normal. #Dysphagia ___ prior radiation: Poor nutrition at baseline as he has dysphagia to solids. Currently followed by SLP at ___. Medications were given as liquids whenever possibile. Full liquid diet was ordered with 2 nutrition supplements at each meal. #Dyspnea: Most likley acutely decompensated in setting of pneumonia and effusions. However, he describes progressive decline in respiratory status over the course of years which he also attributes to chemo and radiation side effects. He has a pulm initial evaluation scheduled for this ___. #Constipation: At the time of discharge, he is taking Milk of magnesia daily, Psyllium BID and mag citrate PRN for management of his narcotic induced constipation. # Anxiety: Patient experienced significant anxiety while his chest tube was in place. THis responded well to lorazepam and self-resolved when his pigtail was removed. # Code: full code # Emergency Contact: ___, Brother, ___ TRANSITIONAL ISSUES: - Please follow-up pending pleural fluid cytology from ___. ___ Pathology requested tissue specimens from patient's prior malignancy to rule out recurrence as the cause of pneumonia/effusion. Transfer of specimens has been requested as a Records Release was faxed to ___ ___ where patient's Pathology specimens were reported to be located. - Patient will complete 2 additional weeks of linezolid after discharge with end date of ___. Please provide patient with a prescription for remaining course of linezolid that remains after leaving rehab. Please call and fax new prescription of linezolid to patient's pharmacy (Stop & Shop in ___ Phone Number ___ 24 hours prior to discharge from rehab as the pharmacy will need to order the liquid linezolid in advance. - Patient will be followed by ___ infectious disease. All questions regarding outpatient parenteral antibiotics after discharge should be directed to the ___ R.N.s at ___ or to the on-call ID fellow when the clinic is closed. - Please continue aggressive bowel regimen while patient is taking narcotics due to pain from his fractured ribs. - Please draw weekly CBC with differential while patient is on linezolid and fax results to ___ at ___. - Please follow-up pending blood cultures from ___. - Please continue to wean oxygen as tolerated. - Please follow-up with Dr. _. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_le ...
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/trl/trainer/utils.py:150: UserWarning: Could not find response key `[26289, 363, 278, 16500, 29901]` in the following instance: <s> Summarize for the patient what happened during the hospital stay based on this doctor's note:
# ...
#   warnings.warn(
#
#  79% 79/100 [00:32<00:08,  2.36it/s]/usr/local/lib/python3.11/dist-packages/trl/trainer/utils.py:150: UserWarning: Could not find response key `[26289, 363, 278, 16500, 29901]` in the following instance: <s> Summarize for the patient what happened during the hospital stay based on this doctor's note:
# Brief Hospital Course: This is a ___ yo F with T1DM, asthma, and other medical conditions presented with left sided hallux ulcer with fevers and malaise over past two weeks, admitted on ___ and discharged on ___ #. Left toe ulcer. Likely osteomyelitis Patient is at high risk of developing osteomyelitis given long standing uncontrolled T1DM. Her exam findings, elevated inflammatory markers, and radiographic evidence are suggestive of osteomyelitis (although podiatry reported initial air seen on foot X-ray was after they had initially opened the wound in the ED). She received antibiotics in the ED, which is likely going to lower yield of the biopsy cultures. Patient was placed on antibiotics- vancomycin, ciprofloxacin, and ceftriaxone- to cover gram positive skin flora, pseudomonas, and also strep given positive swab culture (Day 1, ___. Patient underwent first debridement on ___ and a second debridement with amputation of left hallux on ___ by podiatry. Vascular surgery was consulted for trans-metatarsal amputation. ___ Debridement of skin, subcutaneous tissues and bone, left forefoot. Her pain was managed by standing acetaminophen and IV prn Dilaudid. She did recieve definitive TMA. Does have a sinus tract that currently is packed. #. Asthma. Patient also presented with significant wheezing with normal O2 saturation. CXR was negative for other pulmonary process. Patient was kept on home dose of montelukast 10 mg daily and ___ BID. She was also started on scheduled nebulizers every 3 hours. 40 mg prednisone was given on ___ given significant wheeze and the up-coming procedures given that she has had history of intubation ___ asthma many years ago. #. Type 1 DM. Patient was initially started with home dose Lantus and ISS. Her blood sugar was much more elevated after receiving the prednisone on ___. Her insulin was adjusted to ****** upon discharge. #. Iron deficiency anemia. Patient was noted to have microcytic anemia on presentation. Iron studies showed low iron and unexpectedly low ferritin in the setting of active infection, making her diagnosis more likely iron deficiency anemia. Iron supplement was started. #. Left breast calcification. Incidental finding on CXR. Patient will need to have outpatient mammography to screen for breast cancer. #. Stomach-ache ___. Possibly from hunger as it improved with eating, but could also potentially have gastric erosion and gastritis. She was NPO for the most part on ___ and ___. Ranitidine 150 mg BID was started. NSAIDs were held for pain given possible gastritis. #. Hyponatremia. Patient presented with hyponatremia, likely from hypovolemia in the setting of reduced po intake and insensible loss from fever as well as from elevated blood sugar. Patient received IV fluid, and it resolved. #. Hypertension. Patient was normotensive while in the hospital. She continued with home lisinopril. #. Hyperlipidemia. Patient continued with home simvastatin. #. Depression. Patient initially said that she takes cymbalta 60 mg, but later reported taking 40 mg of Prozac in the morning and 20 mg of Prozac in the evening. She was given her home Prozac. Social work was consulted for coping given the prospect of having TMA and to assist patient with resources. #. Code Status - Full (confirmed with patient). ___ contact boyfriend ___ ___ ___ on Admission: 1. ___ 250/50 BID 2. singulair 10 mg daily 3. albuterol nebs PRN 4. lantus 44 units qAM 5. humalog sliding scale 6. lisinopril 40 mg daily 7. simvastatin 20 mg daily 8. cymbal. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_length`.
#   warnings.warn(
#
#  80% 80/100 [00:32<00:08,  2.27it/s]
#  81% 81/100 [00:33<00:08,  2.19it/s]
#  82% 82/100 [00:33<00:08,  2.17it/s]
#  83% 83/100 [00:34<00:07,  2.14it/s]
#  84% 84/100 [00:34<00:07,  2.15it/s]
#  85% 85/100 [00:35<00:06,  2.16it/s]
#  86% 86/100 [00:35<00:06,  2.17it/s]
#  87% 87/100 [00:36<00:05,  2.24it/s]
#  88% 88/100 [00:36<00:05,  2.30it/s]
#  89% 89/100 [00:36<00:04,  2.37it/s]
#  90% 90/100 [00:37<00:04,  2.41it/s]
#  91% 91/100 [00:37<00:03,  2.45it/s]
#  92% 92/100 [00:37<00:03,  2.55it/s]
#  93% 93/100 [00:38<00:02,  2.64it/s]
#  94% 94/100 [00:38<00:02,  2.71it/s]
#  95% 95/100 [00:38<00:01,  2.79it/s]
#  96% 96/100 [00:39<00:01,  2.87it/s]
#  97% 97/100 [00:39<00:01,  2.93it/s]
#  98% 98/100 [00:39<00:00,  3.06it/s]
#  99% 99/100 [00:40<00:00,  3.26it/s]
#
# {'eval_loss': nan, 'eval_runtime': 40.9197, 'eval_samples_per_second': 2.444, 'eval_steps_per_second': 2.444, 'eval_num_tokens': 1231035.0, 'eval_mean_token_accuracy': 0.5352506613731385, 'epoch': 14.32}
# 100% 100/100 [1:07:36<00:00, 34.67s/it]
# 100% 100/100 [00:40<00:00,  3.42it/s]
#                                      Saving model checkpoint to /content/drive/MyDrive/DL4H-Project/mimic-iv-note-di-bhc/models/Llama-2-7b-hf/mimic-iv-note-di-bhc_Llama-2-7b-hf_4000_600_chars_100_valid/lora_rank_8_lora_alpha_8_lora_dropout_0.05_num_target_modules_2_learning_rate_2e-5/checkpoint-100
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--meta-llama--Llama-2-7b-hf/snapshots/01c7f73d771dfac7d292323805ebc428287df4f9/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 11008,
#   "max_position_embeddings": 4096,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 32,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 10000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.51.3",
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:250: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# tokenizer config file saved in /content/drive/MyDrive/DL4H-Project/mimic-iv-note-di-bhc/models/Llama-2-7b-hf/mimic-iv-note-di-bhc_Llama-2-7b-hf_4000_600_chars_100_valid/lora_rank_8_lora_alpha_8_lora_dropout_0.05_num_target_modules_2_learning_rate_2e-5/checkpoint-100/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/DL4H-Project/mimic-iv-note-di-bhc/models/Llama-2-7b-hf/mimic-iv-note-di-bhc_Llama-2-7b-hf_4000_600_chars_100_valid/lora_rank_8_lora_alpha_8_lora_dropout_0.05_num_target_modules_2_learning_rate_2e-5/checkpoint-100/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 4076.0015, 'train_samples_per_second': 0.393, 'train_steps_per_second': 0.025, 'train_loss': 1.7195496273040771, 'num_tokens': 1231035.0, 'mean_token_accuracy': 0.5423426756520844, 'epoch': 14.32}
# 100% 100/100 [1:07:55<00:00, 40.76s/it]
# Saving model checkpoint to /content/drive/MyDrive/DL4H-Project/mimic-iv-note-di-bhc/models/Llama-2-7b-hf/mimic-iv-note-di-bhc_Llama-2-7b-hf_4000_600_chars_100_valid/lora_rank_8_lora_alpha_8_lora_dropout_0.05_num_target_modules_2_learning_rate_2e-5/best_val_loss
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--meta-llama--Llama-2-7b-hf/snapshots/01c7f73d771dfac7d292323805ebc428287df4f9/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 11008,
#   "max_position_embeddings": 4096,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 32,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 10000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.51.3",
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# /usr/local/lib/python3.11/dist-packages/peft/utils/save_and_load.py:250: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# tokenizer config file saved in /content/drive/MyDrive/DL4H-Project/mimic-iv-note-di-bhc/models/Llama-2-7b-hf/mimic-iv-note-di-bhc_Llama-2-7b-hf_4000_600_chars_100_valid/lora_rank_8_lora_alpha_8_lora_dropout_0.05_num_target_modules_2_learning_rate_2e-5/best_val_loss/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/DL4H-Project/mimic-iv-note-di-bhc/models/Llama-2-7b-hf/mimic-iv-note-di-bhc_Llama-2-7b-hf_4000_600_chars_100_valid/lora_rank_8_lora_alpha_8_lora_dropout_0.05_num_target_modules_2_learning_rate_2e-5/best_val_loss/special_tokens_map.json
#
# Predicting test examples.
# /content/drive/MyDrive/DL4H-Project/patient_summaries_with_llms/summarization/fine_tune_llama.py:291: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:315: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/DL4H-Project/patient_summaries_with_llms/summarization/fine_tune_llama.py", line 438, in <module>
#     main()
#   File "/content/drive/MyDrive/DL4H-Project/patient_summaries_with_llms/summarization/fine_tune_llama.py", line 409, in main
#     predictions_test = predict(trained_model, data_test)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/DL4H-Project/patient_summaries_with_llms/summarization/fine_tune_llama.py", line 292, in predict
#     generation_output = prediction_model.generate(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/peft/peft_model.py", line 1875, in generate
#     outputs = self.base_model.generate(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py", line 2465, in generate
#     result = self._sample(
#              ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py", line 3434, in _sample
#     outputs = model_forward(**model_inputs, return_dict=True)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py", line 965, in wrapper
#     output = func(self, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/utils/deprecation.py", line 172, in wrapped_func
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py", line 821, in forward
#     outputs: BaseModelOutputWithPast = self.model(
#                                        ^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py", line 965, in wrapper
#     output = func(self, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py", line 571, in forward
#     layer_outputs = decoder_layer(
#                     ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py", line 334, in forward
#     hidden_states = self.mlp(hidden_states)
#                     ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py", line 172, in forward
#     down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#                                            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py", line 990, in forward
#     out = bnb.matmul(x, self.weight, bias=self.bias, state=self.state)
#                                           ^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1915, in __getattr__
#     def __getattr__(self, name: str) -> Union[Tensor, "Module"]:
#
# KeyboardInterrupt
# wandb:
# wandb: 🚀 View run frosty-leaf-48 at: https://wandb.ai/naveenkcb-university-of-illinois-urbana-champaign/mimic-iv-note-di-bhc_Llama-2-7b-hf_parameter-tuning/runs/9c0qipxm
# wandb: Find logs at: wandb/run-20250430_043300-9c0qipxm/logs

# %% [markdown]
# The below cell is needed ony for evaluation

# %%
# !ls /content/drive/MyDrive/DL4H-Project/mimic-iv-note-di-bhc/dataset
# Out:
# test_4000_600_chars.json		train_4000_600_chars_251-350_pt.json
# train_4000_600_chars_250_labeling.json	valid_4000_600_chars.json

# %%
```
2025-04-28 14:23:04
***** Running training *****
103
2025-04-28 14:23:04
  Num examples = 100
104
2025-04-28 14:23:04
  Num Epochs = 17
105
2025-04-28 14:23:04
  Instantaneous batch size per device = 1
106
2025-04-28 14:23:04
  Total train batch size (w. parallel, distributed & accumulation) = 16
107
2025-04-28 14:23:04
  Gradient Accumulation steps = 16
108
2025-04-28 14:23:04
  Total optimization steps = 100
109
2025-04-28 14:23:04
  Number of trainable parameters = 4,194,304
```

# %%
# With data_files["test"] = test_4000_600_chars_last_100.json

#python summarization/fine_tune_llama.py --model_name_or_path meta-llama/Llama-2-7b-hf  --evaluation --evaluation_model_path /home/s_hegs02/mimic-iv-note-di-bhc/models/Llama-2-7b-hf/mimic-iv-note-di-bhc_Llama-2-7b-hf_4000_600_chars_100_valid_done/lora_rank_8_lora_alpha_32_lora_dropout_0.1_num_target_modules_2_learning_rate_2e-5/best_val_loss --data_path /home/s_hegs02/mimic-iv-note-di-bhc/dataset --output_path /home/s_hegs02/mimic-iv-note-di-bhc/models/Llama-2-7b-hf/mimic-iv-note-di-bhc_Llama-2-7b-hf_4000_600_chars_100_valid_done/lora_rank_8_lora_alpha_32_lora_dropout_0.1_num_target_modules_2_learning_rate_2e-5_test --num_train_examples 100 --num_val_examples 100 --num_test_examples 100

{'rouge1': 38.18726652084839, 'rouge2': 12.522356326993874, 'rouge3': 5.300379506691891, 'rouge4': 2.6844528863937667, 'rougeL': 23.425086591887453, 'words': 104.15, 'bert_score': 84.68257343769073, 'bert_score_deberta-large': 58.7152236700058, 'sari': 43.39504555237768}
{'rouge1': 36.55885611308579, 'rouge2': 11.770071884328013, 'rouge3': 4.96413117973415, 'rouge4': 2.3760043053086815, 'rougeL': 22.520381900800416, 'words': 100.56, 'bert_score': 82.0653041601181, 'bert_score_deberta-large': 56.56696653366089, 'sari': 41.94318296286558}
{'rouge1': 36.865581109022166, 'rouge2': 12.035793003259116, 'rouge3': 5.477773544226487, 'rouge4': 2.831216527519416, 'rougeL': 22.85251778524732, 'words': 94.03, 'bert_score': 81.28817218542099, 'bert_score_deberta-large': 56.447242498397834, 'sari': 42.631882102051144}
{'rouge1': 36.45585401833812, 'rouge2': 11.507301855132011, 'rouge3': 4.979182106965462, 'rouge4': 2.525371873858721, 'rougeL': 22.339373505129323, 'words': 100.47, 'bert_score': 82.16391408443451, 'bert_score_deberta-large': 56.96498113870621, 'sari': 42.04524834049528}
{'rouge1': 36.698585402455606, 'rouge2': 11.78729495150544, 'rouge3': 4.868574815166207, 'rouge4': 2.2399180637599803, 'rougeL': 22.530625996895047, 'words': 103.47, 'bert_score': 81.9952797293663, 'bert_score_deberta-large': 56.640745639801025, 'sari': 42.02560221098953}

# %% [markdown]
# Error:
#
# TypeError: SFTTrainer.__init__() got an unexpected keyword argument 'max_seq_length'
#
# Fix:
#
# removed the parameter from SFTTTrainer

# %%
#python summarization/fine_tune_llama.py --model_name_or_path meta-llama/Llama-2-7b-hf --num_train_examples 100 --num_val_examples 100 --num_test_examples 100

# %%
# !pip list
